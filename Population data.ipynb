# %%
# Import all libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# Import population data from excel file
pop_data_file = Path("SUB-IP-EST2022-POP.xlsx") 

pop_data = pd.read_excel(pop_data_file)

pop_data.head(20)
# Out:
#    table with row headers in column A and column headers in rows 3 through 4 (leading dots indicate sub-parts)  \
# 0   Annual Estimates of the Resident Population fo...
# 1                                     Geographic Area
# 2                                                 NaN
# 3                             Abbeville city, Alabama
# 4                            Adamsville city, Alabama
# 5                               Addison town, Alabama
# 6                                 Akron town, Alabama
# 7                             Alabaster city, Alabama
# 8                           Albertville city, Alabama
# 9                        Alexander City city, Alabama
# 10                           Aliceville city, Alabama
# 11                              Allgood town, Alabama
# 12                              Altoona town, Alabama
# 13                            Andalusia city, Alabama
# 14                             Anderson town, Alabama
# 15                             Anniston city, Alabama
# 16                                 Arab city, Alabama
# 17                              Ardmore town, Alabama
# 18                                 Argo town, Alabama
# 19                               Ariton town, Alabama
#
#                        Unnamed: 1                          Unnamed: 2  \
# 0                             NaN                                 NaN
# 1   April 1, 2020\nEstimates Base  Population Estimate (as of July 1)
# 2                             NaN                                2020
# 3                            2355                                2356
# 4                            4372                                4360
# 5                             661                                 659
# 6                             227                                 226
# 7                           33330                               33385
# 8                           22392                               22407
# 9                           14847                               14822
# 10                           2172                                2163
# 11                            542                                 541
# 12                            944                                 944
# 13                           8842                                8844
# 14                            253                                 253
# 15                          21562                               21513
# 16                           8443                                8449
# 17                           1322                                1335
# 18                           4361                                4365
# 19                            657                                 655
#
#     Unnamed: 3  Unnamed: 4
# 0          NaN         NaN
# 1          NaN         NaN
# 2       2021.0      2022.0
# 3       2361.0      2366.0
# 4       4292.0      4224.0
# 5        666.0       669.0
# 6        226.0       221.0
# 7      33741.0     33873.0
# 8      22544.0     22726.0
# 9      14701.0     14636.0
# 10      2121.0      2075.0
# 11       544.0       553.0
# 12       942.0       941.0
# 13      8824.0      8790.0
# 14       254.0       254.0
# 15     21343.0     21182.0
# 16      8501.0      8623.0
# 17      1370.0      1393.0
# 18      4379.0      4364.0
# 19       657.0       659.0
